# %% [markdown]
# # Secara Visual

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
sp = pd.read_csv('D:\CSV\sp500.csv')

# %%
sp.shape
# Out:
# (252, 7)

# %%
sp.head()
# Out:
#          Date         Open         High          Low        Close      Volume  \
# 0  2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 1  2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2  2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 3  2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 4  2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#      Adj Close
# 0  2058.199951
# 1  2020.579956
# 2  2002.609985
# 3  2025.900024
# 4  2062.139893

# %%
sp.plot(x='High', y='Low')
# Out:
# <AxesSubplot:xlabel='High'>

# %%
sp.plot(x='High', y='Low', kind='scatter')
plt.xlabel('High')
plt.ylabel('Low')
# Out:
# Text(0, 0.5, 'Low')

# %%
iris.plot(y='Low', kind='box')
plt.ylabel('Low')
# Out:
# Text(0, 0.5, 'Low')

# %%
sp.plot(y='Low', kind='hist')
plt.xlabel('Low')
# Out:
# Text(0.5, 0, 'Low')

# %%
iris.plot(y='Low', kind='hist', bins=30, range=(2000, 2100), density=True)
plt.xlabel('Low')
plt.show()

# %%
iris.plot(y='Low', kind='hist', bins=30, range=(2000,2100), cumulative=True, density=True)
plt.xlabel('Low)')
plt.title('Cumulative distribution function (CDF)')
# Out:
# Text(0.5, 1.0, 'Cumulative distribution function (CDF)')

# %% [markdown]
# # Secara Statistik

# %%
sp.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count   252.000000   252.000000   252.000000   252.000000  2.520000e+02
# mean   2061.268016  2071.862899  2049.336906  2061.067741  3.644994e+09
# std      54.547528    50.389886    58.018454    54.885790  6.750428e+08
# min    1872.750000  1899.479980  1867.010010  1867.609985  5.362000e+08
# 25%    2034.245026  2050.245056  2022.237549  2035.212494  3.243620e+09
# 50%    2078.630004  2086.964966  2067.020019  2079.395019  3.576485e+09
# 75%    2101.605041  2108.432434  2091.502502  2101.152527  4.022002e+09
# max    2130.360107  2134.719971  2126.060059  2130.820068  6.683070e+09
#
#          Adj Close
# count   252.000000
# mean   2061.067741
# std      54.885790
# min    1867.609985
# 25%    2035.212494
# 50%    2079.395019
# 75%    2101.152527
# max    2130.820068

# %%
sp.count()
# Out:
# Date         252
# Open         252
# High         252
# Low          252
# Close        252
# Volume       252
# Adj Close    252
# dtype: int64

# %%
sp['Low'].count()
# Out:
# 252

# %%
sp.mean()
# Out:
# Open         2.061268e+03
# High         2.071863e+03
# Low          2.049337e+03
# Close        2.061068e+03
# Volume       3.644994e+09
# Adj Close    2.061068e+03
# dtype: float64

# %%
sp.std()
# Out:
# Open         5.454753e+01
# High         5.038989e+01
# Low          5.801845e+01
# Close        5.488579e+01
# Volume       6.750428e+08
# Adj Close    5.488579e+01
# dtype: float64

# %%
sp.median()
# Out:
# Open         2.078630e+03
# High         2.086965e+03
# Low          2.067020e+03
# Close        2.079395e+03
# Volume       3.576485e+09
# Adj Close    2.079395e+03
# dtype: float64

# %%
q = 0.5
sp.quantile(q)
# Out:
# Open         2.078630e+03
# High         2.086965e+03
# Low          2.067020e+03
# Close        2.079395e+03
# Volume       3.576485e+09
# Adj Close    2.079395e+03
# Name: 0.5, dtype: float64

# %%
q = [0.25, 0.75]
sp.quantile(q)
# Out:
#              Open         High          Low        Close        Volume  \
# 0.25  2034.245026  2050.245056  2022.237549  2035.212494  3.243620e+09
# 0.75  2101.605041  2108.432434  2091.502502  2101.152527  4.022002e+09
#
#         Adj Close
# 0.25  2035.212494
# 0.75  2101.152527

# %%
sp.min()
# Out:
# Date         2015-01-02
# Open            1872.75
# High            1899.48
# Low             1867.01
# Close           1867.61
# Volume        536200000
# Adj Close       1867.61
# dtype: object

# %%
sp.max()
# Out:
# Date         2015-12-31
# Open            2130.36
# High            2134.72
# Low             2126.06
# Close           2130.82
# Volume       6683070000
# Adj Close       2130.82
# dtype: object

# %%
sp.plot(kind= 'box')
plt.ylabel('[-]')
# Out:
# Text(0, 0.5, '[-]')

# %% [markdown]
# # Filtering

# %%
sp.head()
# Out:
#          Date         Open         High          Low        Close      Volume  \
# 0  2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2708700000
# 1  2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  3799120000
# 2  2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  4460110000
# 3  2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  3805480000
# 4  2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  3934010000
#
#      Adj Close
# 0  2058.199951
# 1  2020.579956
# 2  2002.609985
# 3  2025.900024
# 4  2062.139893

# %%
sp.plot(kind= 'hist', bins=50, range=(2000,2100), alpha=0.4)
plt.title('Entire SP500 data set')
plt.xlabel('[-]')
# Out:
# Text(0.5, 0, '[-]')
